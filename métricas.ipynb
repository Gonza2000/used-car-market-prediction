# %% [markdown]
# # Comparación de Métricas de Modelos
#
# Este cuaderno compara el rendimiento de los tres modelos entrenados: Regresión Lineal, Ridge (L2) y XGBoost.

# %%
# ============================================================
# TABLA COMPARATIVA DE LOS TRES MODELOS
# ============================================================
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

resultados = {
    'Modelo': ['Regresión Lineal', 'Ridge (L2)', 'XGBoost'],
    'MAE (USD)': [
        mean_absolute_error(y_test, y_pred_lr),
        mean_absolute_error(y_test, y_pred_ridge),
        mean_absolute_error(y_test, y_pred)
    ],
    'RMSE (USD)': [
        np.sqrt(mean_squared_error(y_test, y_pred_lr)),
        np.sqrt(mean_squared_error(y_test, y_pred_ridge)),
        np.sqrt(mean_squared_error(y_test, y_pred))
    ],
    'R²': [
        r2_score(y_test, y_pred_lr),
        r2_score(y_test, y_pred_ridge),
        r2_score(y_test, y_pred)
    ]
}

df_resultados = pd.DataFrame(resultados)
df_resultados['MAE (USD)']  = df_resultados['MAE (USD)'].map('${:,.2f}'.format)
df_resultados['RMSE (USD)'] = df_resultados['RMSE (USD)'].map('${:,.2f}'.format)
df_resultados['R²']         = df_resultados['R²'].map('{:.4f}'.format)

print("=== COMPARACIÓN DE MODELOS ===")
print(df_resultados.to_string(index=False))
